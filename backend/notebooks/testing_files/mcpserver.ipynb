# %%
## Server Set-up
from mcp.server.fastmcp import FastMCP

# Create the MCP server
mcp = FastMCP('Road-Design-mcp')

#Add your tools, resources and prompts here ...

# %%
"inputs": [
],
"servers": {
        "learnpythonmcp": {
            "command": "/opt/anaconda3/bin/uv",
            "args": [
                " --directory",
                '.',
                "run",
                "prompts_server.py"
            ],
        }
}
